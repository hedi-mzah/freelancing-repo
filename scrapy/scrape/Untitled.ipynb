# %%
import pandas as pd

# %%
df=pd.read_excel('takafulalarabia.xlsx')

# %%
df
# Out:
#                                             title                 contact  \
# 0                   مجمع المنار الطبي (حي المطار)  tel:هاتف :  0165329966
# 1                    بصريات بدر نجد (حي العزيزية)          tel:0536815183
# 2     مركز بدي تون الرياضي (ط. فهد العلي العريفي)   tel:هاتف : 0581888897
# 3                    مجمع رويال الطبي (حي النقرة)  tel:هاتف :  0165658888
# 4            مراكز المها للبصريات ( جميع الفروع )           tel:920033390
# ...                                           ...                     ...
# 2613                   جمال العيون للنظارات (ثول)          tel:0541037392
# 2614              مركز الحسون للنظارات (حي الصفا)          tel:0126939506
# 2615               رؤى ملونة للنظارات (حي الرحاب)          tel:0586670012
# 2616              مؤسسة رؤية الطبية (حي الفيصلية)          tel:0126835556
# 2617          مركز طاقة الجسم الرياضي (حي الروضة)          tel:0533639911
#
#                                                 address  \
# ...

# %%
type(df['discount_details'][0])
# Out:
# str
